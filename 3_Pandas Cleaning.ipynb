# %% [markdown]
# <a href="https://colab.research.google.com/github/ANUKOOL324/Data_Analytics/blob/main/3_Pandas%20Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_25_Pandas Cleaning.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets

# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %% [markdown]
# ## 🟩 Sort by Salary (1.25.1)

# %%
df.sort_values(by='salary_year_avg' , inplace=True, ignore_index=True)

# %% [markdown]
# ---

# %%
df
# Out:
#           job_title_short                                          job_title  \
# 0           Data Engineer                             Data Engineer - Hadoop
# 1        Business Analyst                                 Operations Analyst
# 2           Data Engineer                    Showwcase Elite - Data Engineer
# 3           Data Engineer                                 Lead Data Engineer
# 4           Data Engineer  Data Engineer Jobs In Flipdish for Engineering...
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df['salary_year_avg']
# Out:
# 0         15000.0
# 1         16500.0
# 2         20000.0
# 3         23496.0
# 4         24000.0
#            ...
# 785736        NaN
# 785737        NaN
# 785738        NaN
# 785739        NaN
# 785740        NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df[df['salary_year_avg'].notna()]
# Out:
#              job_title_short  \
# 0              Data Engineer
# 1           Business Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 21998         Data Scientist
# 21999         Data Scientist
# 22000           Data Analyst
# 22001  Senior Data Scientist
# 22002         Data Scientist
#
#                                                job_title  \
# 0                                 Data Engineer - Hadoop
# 1                                     Operations Analyst
# 2                        Showwcase Elite - Data Engineer
# 3                                     Lead Data Engineer
# 4      Data Engineer Jobs In Flipdish for Engineering...
# ...                                                  ...
# 21998              Staff Data Scientist/Quant Researcher
# 21999  Geographic Information Systems Analyst - GIS A...
# 22000                                       Data Analyst
# ...

# %% [markdown]
# ## 🟩 Create Remote Column (1.25.2)

# %%
#solution
df
# Out:
#           job_title_short                                          job_title  \
# 0           Data Engineer                             Data Engineer - Hadoop
# 1        Business Analyst                                 Operations Analyst
# 2           Data Engineer                    Showwcase Elite - Data Engineer
# 3           Data Engineer                                 Lead Data Engineer
# 4           Data Engineer  Data Engineer Jobs In Flipdish for Engineering...
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df['remote']=df['job_work_from_home']

# %%
df['remote']
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: remote, Length: 785741, dtype: bool

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Extract Year from Date (1.25.3)

# %%
#solution
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date'] # it is object(string type) so make it datatime data type
# Out:
# 0         2023-12-09 10:05:30
# 1         2023-05-16 18:39:05
# 2         2023-07-07 08:20:46
# 3         2023-02-11 19:12:33
# 4         2023-09-23 22:28:39
#                  ...
# 785736    2023-03-13 06:16:16
# 785737    2023-03-12 06:18:18
# 785738    2023-03-12 06:32:36
# 785739    2023-03-12 06:32:15
# 785740    2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: object

# %%
df['job_posted_date']=pd.to_datetime(df.job_posted_date)
df.job_posted_date.dt.year
# Out:
# 0         2023
# 1         2023
# 2         2023
# 3         2023
# 4         2023
#           ...
# 785736    2023
# 785737    2023
# 785738    2023
# 785739    2023
# 785740    2023
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df.job_posted_date.dt.month
# Out:
# 0         12
# 1          5
# 2          7
# 3          2
# 4          9
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Drop Missing Salaries (1.25.4)

# %%
df
# Out:
#           job_title_short                                          job_title  \
# 0           Data Engineer                             Data Engineer - Hadoop
# 1        Business Analyst                                 Operations Analyst
# 2           Data Engineer                    Showwcase Elite - Data Engineer
# 3           Data Engineer                                 Lead Data Engineer
# 4           Data Engineer  Data Engineer Jobs In Flipdish for Engineering...
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df=df.dropna(subset=['salary_year_avg'])

# %%
df['salary_year_avg']
# Out:
# 0         15000.0
# 1         16500.0
# 2         20000.0
# 3         23496.0
# 4         24000.0
#            ...
# 21998    550000.0
# 21999    585000.0
# 22000    650000.0
# 22001    890000.0
# 22002    960000.0
# Name: salary_year_avg, Length: 22003, dtype: float64

# %% [markdown]
# ---
