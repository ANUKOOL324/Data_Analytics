# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_24_Pandas Inspection.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install -U datasets
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.29.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (1.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)

# %% [markdown]
# ---

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %% [markdown]
# ## 🟩 Access Third Row (1.24.1)

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                      ALPHA Augmented Services
# job_skills               ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# job_type_skills          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                      ALPHA Augmented Services
# job_skills               ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# job_type_skills          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# Name: 2, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Unique Job Countries (1.24.2)

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
#        'Malta', 'Indonesia', 'Tunisia', 'Latvia', 'Slovakia', 'Lebanon',
#        'Japan', 'Sri Lanka', 'Slovenia', 'Bangladesh', 'Greece',
#        'Ecuador', 'Oman', 'Kenya', 'Guyana', 'Vietnam', 'Norway',
#        'Senegal', 'El Salvador', 'Iceland', 'Thailand', 'Ghana',
#        'Croatia', 'Myanmar', 'Nepal', 'Morocco', 'Guadeloupe', 'Iraq',
#        'Palestine', 'Guinea', 'Albania', 'Guatemala', 'Qatar', 'Uganda',
#        'Bolivia', None, 'Dominican Republic', 'Ethiopia', 'Haiti',
#        'Uzbekistan', 'Bahamas', 'Liberia', 'Montenegro', 'Cayman Islands',
#        'Mongolia', 'Macedonia (FYROM)', 'Azerbaijan', 'Burkina Faso',
#        'Guam', 'Trinidad and Tobago', 'Benin', 'Kyrgyzstan',
#        'Bosnia and Herzegovina', 'Zambia', 'Cameroon', 'Venezuela',
#        'Barbados', 'Togo', 'Rwanda', 'Cambodia', 'Algeria', 'Afghanistan',
#        'Congo, Democratic Republic of the', 'Zimbabwe', 'Jamaica',
#        'Suriname', 'Mozambique', 'Yemen', 'Tanzania', 'Madagascar',
#        'Mali', 'Paraguay', 'Brunei', 'Malawi', 'Nicaragua', 'Libya',
#        'Tajikistan', 'Mauritania', 'Botswana', 'Fiji',
#        'Northern Mariana Islands', 'Angola', 'Somalia',
#        'Papua New Guinea', 'Gambia', 'Djibouti', 'Laos', 'Curaçao',
#        'Maldives', 'Bhutan'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Filter by Job Schedule Type and Display (1.24.3)

# %%
#df.info()
df.job_schedule_type.unique()
# Out:
# array(['Full-time', 'Contractor and Temp work',
#        'Full-time and Internship', 'Temp work', 'Contractor',
#        'Full-time and Part-time', 'Full-time and Temp work',
#        'Full-time and Contractor', 'Part-time', 'Internship', None,
#        'Part-time and Contractor', 'Temp work and Internship',
#        'Full-time, Part-time, and Contractor',
#        'Full-time, Part-time, and Internship',
#        'Full-time, Contractor, and Temp work',
#        'Full-time, Part-time, and Temp work',
#        'Full-time, Temp work, and Internship',
#        'Full-time, Contractor, and Internship',
#        'Part-time and Internship', 'Contractor and Internship',
#        'Part-time and Full-time', 'Part-time and Temp work',
#        'Full-time and Volunteer', 'Contractor, Temp work, and Internship',
#        'Full-time and Per diem', 'Per diem', 'Volunteer',
#        'Part-time, Contractor, and Temp work',
#        'Full-time, Temp work, and Per diem',
#        'Part-time, Temp work, and Internship', 'Contractor and Part-time',
#        'Part-time and Per diem', 'Contractor and Per diem',
#        'Internship and Full-time', 'Internship and Per diem',
#        'Full-time, Part-time, and Volunteer', 'Temp work and Full-time',
#        'Part-time, Internship, and Volunteer', 'Part-time and Volunteer',
#        'Part-time, Contractor, and Internship',
#        'Internship and Volunteer', 'Contractor and Full-time',
#        'Full-time, Part-time, and Per diem',
#        'Full-time, Contractor, and Volunteer',
#        'Temp work, Full-time, and Part-time', 'Pekerjaan tetap',
#        'Kontraktor'], dtype=object)

# %%
df[df['job_schedule_type']=="Full-time and Internship"]
# Out:
#          job_title_short                                          job_title  \
# 12          Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 31          Data Analyst                           Stage - Data Analyst F/H
# 67          Data Analyst                  Stage - Data Analyste Finance H/F
# 348        Data Engineer                     Data Analytics Engineer Intern
# 575         Data Analyst     2024 Business Intelligence Engineer Internship
# ...                  ...                                                ...
# 784477  Business Analyst                       Business Intelligence Intern
# 784597     Data Engineer                 Data Engineer Internship - Madison
# 784603    Data Scientist                              Data Scientist Intern
# 784805    Data Scientist  Data Science Internship in Hyderabad at First ...
# 785577      Data Analyst                         Audit Data Analytics Co-Op
#
#                                              job_location  \
# 12                                           Lyon, France
# 31                                          Paris, France
# 67                                          Paris, France
# 348                                        Stonehouse, UK
# 575                                            London, UK
# ...                                                   ...
# 784477  Kuala Lumpur, Federal Territory of Kuala Lumpu...
# 784597                                        Madison, WI
# 784603                                        Indiana, PA
# 784805                      Morena, Madhya Pradesh, India
# 785577                                      Covington, GA
#
#                         job_via         job_schedule_type  job_work_from_home  \
# 12                 via Jobijoba  Full-time and Internship               False
# 31                 via LinkedIn  Full-time and Internship               False
# 67      via Emplois Trabajo.org  Full-time and Internship               False
# 348                via LinkedIn  Full-time and Internship               False
# 575                via LinkedIn  Full-time and Internship               False
# ...                         ...                       ...                 ...
# 784477          via Trabajo.org  Full-time and Internship               False
# 784597             via LinkedIn  Full-time and Internship               False
# 784603          via Trabajo.org  Full-time and Internship               False
# 784805         via Talents Jobs  Full-time and Internship               False
# 785577          via Trabajo.org  Full-time and Internship               False
#
#              search_location      job_posted_date  job_no_degree_mention  \
# 12                    France  2023-12-22 13:24:41                  False
# 31                    France  2023-10-19 13:59:31                  False
# 67                    France  2023-11-07 13:37:53                  False
# 348           United Kingdom  2023-12-28 14:01:56                  False
# 575           United Kingdom  2023-12-19 13:34:57                  False
# ...                      ...                  ...                    ...
# 784477              Malaysia  2023-11-07 07:11:43                  False
# 784597  Texas, United States  2023-09-26 06:08:41                  False
# 784603               Georgia  2023-10-22 07:05:38                  False
# 784805                 India  2023-12-24 06:09:25                  False
# 785577               Georgia  2023-09-10 06:32:47                  False
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 12                     False          France        None              NaN
# 31                     False          France        None              NaN
# 67                     False          France        None              NaN
# 348                    False  United Kingdom        None              NaN
# 575                    False  United Kingdom        None              NaN
# ...                      ...             ...         ...              ...
# 784477                 False        Malaysia        None              NaN
# 784597                 False   United States        None              NaN
# 784603                  True   United States        None              NaN
# 784805                 False           India        None              NaN
# 785577                 False   United States        None              NaN
#
#         salary_hour_avg                                       company_name  \
# 12                  NaN                                              Engie
# 31                  NaN  GROUPE BON MARCHÉ : Le Bon Marché Rive Gauche ...
# 67                  NaN                                   Kepler Cheuvreux
# 348                 NaN                                                SLB
# 575                 NaN                                             Amazon
# ...                 ...                                                ...
# 784477              NaN                                             Shopee
# 784597              NaN                                              Fetch
# 784603              NaN                                           Experian
# 784805              NaN          Aerospace and Defense Talent IT Solutions
# 785577              NaN                                        Fifth Third
#
#                                                job_skills  \
# 12      ['sql', 'php', 'excel', 'power bi', 'sap', 'ji...
# 31                                                ['sql']
# 67                                              ['excel']
# 348     ['python', 'sql', 'pandas', 'numpy', 'matplotl...
# 575     ['sql', 'python', 'java', 'r', 'aws', 'excel',...
# ...                                                   ...
# 784477               ['python', 'sql', 'excel', 'sheets']
# 784597  ['python', 'sql', 'shell', 'nosql', 'mongodb',...
# 784603                    ['python', 'sql', 'sas', 'sas']
# 784805                                               None
# 785577  ['sas', 'sas', 'python', 'sql', 'r', 'visual b...
#
#                                           job_type_skills
# 12      {'analyst_tools': ['excel', 'power bi', 'sap']...
# 31                               {'programming': ['sql']}
# 67                           {'analyst_tools': ['excel']}
# 348     {'libraries': ['pandas', 'numpy', 'matplotlib'...
# 575     {'analyst_tools': ['excel', 'tableau', 'cognos...
# ...                                                   ...
# 784477  {'analyst_tools': ['excel', 'sheets'], 'progra...
# 784597  {'cloud': ['snowflake'], 'databases': ['mongod...
# 784603  {'analyst_tools': ['sas'], 'programming': ['py...
# 784805                                               None
# 785577  {'analyst_tools': ['sas', 'tableau', 'excel'],...
#
# [2340 rows x 17 columns]

# %%
#df.info()
print(df.job_title.unique())
print(df.job_skills.unique())
df
# Out:
# ['Senior Clinical Data Engineer / Principal Clinical Data Engineer ...'
#  'Data Analyst' 'Data Engineer/Scientist/Analyst, Mid or Senior (m/f/x)'
#  ... 'PreSales Engineer' 'Commercial Analyst - Start Now'
#  'AWS System Analyst']
# [None "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"
#  "['python', 'sql', 'c#', 'azure', 'airflow', 'dax', 'docker', 'kubernetes', 'jenkins']"
#  ... "['sql', 'bigquery', 'gdpr', 'git', 'gitlab', 'github']"
#  "['sql', 'python', 'bigquery', 'aws', 'airflow', 'fastapi', 'github', 'docker']"
#  "['bash', 'python', 'perl', 'linux', 'unix', 'kubernetes', 'docker', 'ansible']"]
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]

# %%
df[(df["job_title"]=="Data Analyst")&(df["job_country"]=="India")]
# Out:
#        job_title_short     job_title                 job_location  \
# 159       Data Analyst  Data Analyst  Hyderabad, Telangana, India
# 194       Data Analyst  Data Analyst                        India
# 504       Data Analyst  Data Analyst  Hyderabad, Telangana, India
# 691       Data Analyst  Data Analyst                        India
# 1399      Data Analyst  Data Analyst     Pune, Maharashtra, India
# ...                ...           ...                          ...
# 784845    Data Analyst  Data Analyst  Bengaluru, Karnataka, India
# 785157    Data Analyst  Data Analyst  Hyderabad, Telangana, India
# 785515    Data Analyst  Data Analyst  Bengaluru, Karnataka, India
# 785548    Data Analyst  Data Analyst  Bengaluru, Karnataka, India
# 785628    Data Analyst  Data Analyst     Gurugram, Haryana, India
#
#                 job_via job_schedule_type  job_work_from_home search_location  \
# 159        via LinkedIn        Contractor               False           India
# 194     via BeBee India         Full-time               False           India
# 504           via Shine         Full-time               False           India
# 691     via BeBee India         Full-time               False           India
# 1399       via LinkedIn         Full-time               False           India
# ...                 ...               ...                 ...             ...
# 784845     via LinkedIn         Full-time               False           India
# 785157     via LinkedIn         Full-time               False           India
# 785515  via Ai-Jobs.net         Full-time               False           India
# 785548     via LinkedIn         Full-time               False           India
# 785628     via LinkedIn         Full-time               False           India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 159     2023-11-28 13:12:07                  False                 False
# 194     2023-06-20 13:11:10                  False                 False
# 504     2023-11-12 13:08:06                   True                 False
# 691     2023-09-12 13:14:38                   True                 False
# 1399    2023-07-04 13:13:00                   True                 False
# ...                     ...                    ...                   ...
# 784845  2023-01-25 06:14:59                   True                 False
# 785157  2023-01-31 06:11:12                  False                 False
# 785515  2023-09-01 06:17:34                  False                 False
# 785548  2023-01-19 06:14:17                  False                 False
# 785628  2023-01-09 06:08:12                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 159          India        None              NaN              NaN
# 194          India        None              NaN              NaN
# 504          India        None              NaN              NaN
# 691          India        None              NaN              NaN
# 1399         India        None              NaN              NaN
# ...            ...         ...              ...              ...
# 784845       India        None              NaN              NaN
# 785157       India        None              NaN              NaN
# 785515       India        year         105000.0              NaN
# 785548       India        None              NaN              NaN
# 785628       India        None              NaN              NaN
#
#                                company_name  \
# 159               Fusion Plus Solutions Inc
# 194          QuEST Global Services Pte. Ltd
# 504                                    HSBC
# 691                                     AOS
# 1399                            Infosys BPM
# ...                                     ...
# 784845                            Capgemini
# 785157                     ARYAN TECHNOLOGY
# 785515                               Myntra
# 785548                        Artech L.L.C.
# 785628  GUS Global Services India Pvt. Ltd.
#
#                                                job_skills  \
# 159                                               ['sql']
# 194     ['python', 'sql', 'excel', 'ms access', 'power...
# 504     ['sql', 'nosql', 'python', 'r', 'mysql', 'sql ...
# 691                                                  None
# 1399    ['sql', 'shell', 'r', 'bigquery', 'pandas', 'l...
# ...                                                   ...
# 784845                                   ['sql', 'visio']
# 785157  ['sql', 'javascript', 'sas', 'sas', 'excel', '...
# 785515                                               None
# 785548                                   ['sql', 'excel']
# 785628  ['r', 'python', 'sql', 'sap', 'power bi', 'tab...
#
#                                           job_type_skills
# 159                              {'programming': ['sql']}
# 194     {'analyst_tools': ['excel', 'ms access', 'powe...
# 504     {'analyst_tools': ['qlik', 'tableau', 'power b...
# 691                                                  None
# 1399    {'analyst_tools': ['excel', 'tableau', 'qlik']...
# ...                                                   ...
# 784845  {'analyst_tools': ['visio'], 'programming': ['...
# 785157  {'analyst_tools': ['sas', 'excel', 'spss'], 'p...
# 785515                                               None
# 785548  {'analyst_tools': ['excel'], 'programming': ['...
# 785628  {'analyst_tools': ['sap', 'power bi', 'tableau...
#
# [1539 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Check Missing Values (1.24.4)

# %%
df.isnull()
# Out:
#         job_title_short  job_title  job_location  job_via  job_schedule_type  \
# 0                 False      False         False    False              False
# 1                 False      False         False    False              False
# 2                 False      False         False    False              False
# 3                 False      False         False    False              False
# 4                 False      False         False    False              False
# ...                 ...        ...           ...      ...                ...
# 785736            False      False         False    False              False
# 785737            False      False         False    False              False
# 785738            False      False         False    False              False
# 785739            False      False         False    False              False
# 785740            False      False         False    False              False
#
#         job_work_from_home  search_location  job_posted_date  \
# 0                    False            False            False
# 1                    False            False            False
# 2                    False            False            False
# 3                    False            False            False
# 4                    False            False            False
# ...                    ...              ...              ...
# 785736               False            False            False
# 785737               False            False            False
# 785738               False            False            False
# 785739               False            False            False
# 785740               False            False            False
#
#         job_no_degree_mention  job_health_insurance  job_country  salary_rate  \
# 0                       False                 False        False         True
# 1                       False                 False        False         True
# 2                       False                 False        False         True
# 3                       False                 False        False         True
# 4                       False                 False        False         True
# ...                       ...                   ...          ...          ...
# 785736                  False                 False        False         True
# 785737                  False                 False        False         True
# 785738                  False                 False        False         True
# 785739                  False                 False        False         True
# 785740                  False                 False        False         True
#
#         salary_year_avg  salary_hour_avg  company_name  job_skills  \
# 0                  True             True         False        True
# 1                  True             True         False       False
# 2                  True             True         False       False
# 3                  True             True         False       False
# 4                  True             True         False       False
# ...                 ...              ...           ...         ...
# 785736             True             True         False       False
# 785737             True             True         False       False
# 785738             True             True         False       False
# 785739             True             True         False       False
# 785740             True             True         False       False
#
#         job_type_skills
# 0                  True
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 785736            False
# 785737            False
# 785738            False
# 785739            False
# 785740            False
#
# [785741 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# job_title_short               0
# job_title                     1
# job_location               1045
# job_via                       8
# job_schedule_type         12667
# job_work_from_home            0
# search_location               0
# job_posted_date               0
# job_no_degree_mention         0
# job_health_insurance          0
# job_country                  49
# salary_rate              752674
# salary_year_avg          763738
# salary_hour_avg          775079
# company_name                 18
# job_skills               117037
# job_type_skills          117037
# dtype: int64

# %%
round(df.isna().mean()*100,2)
# Out:
# job_title_short           0.00
# job_title                 0.00
# job_location              0.13
# job_via                   0.00
# job_schedule_type         1.61
# job_work_from_home        0.00
# search_location           0.00
# job_posted_date           0.00
# job_no_degree_mention     0.00
# job_health_insurance      0.00
# job_country               0.01
# salary_rate              95.79
# salary_year_avg          97.20
# salary_hour_avg          98.64
# company_name              0.00
# job_skills               14.90
# job_type_skills          14.90
# dtype: float64

# %% [markdown]
# ---
